# %% [markdown]
# ✓ Crete  "Matrix Opertions Tool" using Python nd the NumPy library. The appliction should
# allow users to input mtrices and perform opertions like addition, subtrction,
# multipliction, transpose, and determinnt calcultion. Include an interctive interface to
# dispaly results in  structured format.

# %%
import numpy as np

a = []
print("enter data for 1st mtrix -")
row = int(input("enter the no. of rows you want :"))
column = int(input("enter the no. of columns you want :"))
for i in range(row*column):
    a.append(int(input("enter the data :")))
a = np.array(a).reshape(row,column)


b = []
print("enter data for 2st mtrix -")
row = int(input("enter the no. of rows you want :"))
column = int(input("enter the no. of columns you want :"))
for i in range(row*column):
   b.append(int(input("enter the data :")))
b = np.array(b).reshape(row,column)


def addition(a, b):
    """Performs matrix addition."""
    if a.shape == b.shape:
        return a + b
    else:
        return "Error: Matrices must have the same dimensions for addition."

def subtraction(a, b):
    """Performs matrix subtraction."""
    if a.shape == b.shape:
        return a - b
    else:
        return "Error: Matrices must have the same dimensions for subtraction."

def multiplication(a, b):
    """Performs matrix multiplication."""
    if a.shape[1] == b.shape[0]:
        return np.dot(a, b)
    else:
        return "Error: Number of columns in the first matrix must equal the number of rows in the second matrix for multiplication."

def transpose(a,b):
    """Performs matrix transpose."""
    mat = input("enter matrix (a/b) : ")
    if mat == "a":
        return a.T
    elif mat == "b":
        return b.T
    else:
        return "invalid choice"
def determinant(a,b):
    """Calculates the determinant of a square matrix."""
    mat = input("enter a choice (a/b) : ")
    if mat == "a":
      if a.shape[0] == a.shape[1]:
        return np.linalg.det(a)
      else:
         return "Error: Determinant can only be calculated for square matrices."
    elif mat =="b":
      if b.shape[0] == b.shape[1]:
        return np.linalag.det(b)
      else:
        return "error"
    else:
      return "invalid choice"

while True:
    print("\nMatrix Operations Tool")
    print("1. Get Matrix Input")
    print("2. Perform Addition")
    print("3. Perform Subtraction")
    print("4. Perform Multiplication")
    print("5. Perform Transpose")
    print("6. Calculate Determinant")
    print("7. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
       print("matrix 1st is:")
       print(a)
       print("matrix 2nd is:")
       print(b)
    elif choice == 2:
        result = addition(a, b)
        print("Result of Addition:")
        print(result)
    elif choice == 3:
      result = subtraction(a,b)
      print("resulted matrix :")
      print(result)
    elif choice == 4:
      result = multiplication(a,b)
      print(result)
    elif choice == 5:
      result = transpose(a,b)
      print(result)
    elif choice == 6:
      result = determinant(a,b)
      print(result)
    elif choice == 7:
      print("thank you")
      break
    else:
      print("invalid input")
# Out:
# enter data for 1st mtrix -
# enter the no. of rows you want :2
# enter the no. of columns you want :2
# enter the data :4
# enter the data :5
# enter the data :4
# enter the data :3
# enter data for 2st mtrix -
# enter the no. of rows you want :2
# enter the no. of columns you want :2
# enter the data :54
# enter the data :554
# enter the data :545
# enter the data :3
#
# Matrix Operations Tool
# 1. Get Matrix Input
# 2. Perform Addition
# 3. Perform Subtraction
# 4. Perform Multiplication
# 5. Perform Transpose
# 6. Calculate Determinant
# 7. Exit
# Enter your choice: 1
# matrix 1st is:
# [[4 5]
#  [4 3]]
# matrix 2nd is:
# [[ 54 554]
#  [545   3]]
#
# Matrix Operations Tool
# 1. Get Matrix Input
# 2. Perform Addition
# 3. Perform Subtraction
# 4. Perform Multiplication
# 5. Perform Transpose
# 6. Calculate Determinant
# 7. Exit
# Enter your choice: 7
# thank you
